# %%
import numpy as np
import pandas as pd
import seaborn as sns

df = pd.read_csv('../Datasets/titanic.csv')

df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df.Age.median()
# Out:
# 28.0

# %%
df.Age.mean()
# Out:
# 29.69911764705882

# %%
df.Age.hist()

# %%
df.Age.hist(bins=16)

# %%
df[df.Sex == 'female'].Age.hist(bins=21)

# %%
df[df.Sex == 'male'].Age.hist(bins=80)

# %%
df.Age.isna().sum()
# Out:
# 177

# %%
df['Gender'] = df.Sex.apply(lambda sex: 1 if sex == 'male' else 0)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Gender
# 0      0         A/5 21171   7.2500   NaN        S       1
# 1      0          PC 17599  71.2833   C85        C       0
# 2      0  STON/O2. 3101282   7.9250   NaN        S       0
# 3      0            113803  53.1000  C123        S       0
# ...

# %%
df.Age.plot.box()

# %%
df[df.Sex == 'male'].Age.plot.box()

# %%
df[df.Sex == 'female'].Age.plot.box()

# %%
df[(df.Age.isna() == False) & (df.Cabin.isna() == False)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# 21            22         1       2
# 23            24         1       1
# 27            28         0       1
# 52            53         1       1
# 54            55         0       1
# 61            62         1       1
# 62            63         0       1
# 66            67         1       2
# 75            76         0       3
# 88            89         1       1
# 92            93         0       1
# 96            97         0       1
# 97            98         1       1
# 102          103         0       1
# 110          111         0       1
# 118          119         0       1
# 123          124         1       2
# 124          125         0       1
# 136          137         1       1
# 137          138         0       1
# ...

# %%
df[df.Embarked == 'C'].Age.hist(bins=12)

# %%
df.Embarked.describe()
# Out:
# count     889
# unique      3
# top         S
# freq      644
# Name: Embarked, dtype: object

# %%
df.Embarked.hist(bins=3)

# %%
len(df[df.Embarked == 'C'])
# Out:
# 168

# %%
df.Embarked.value_counts().plot(kind='bar')

# %%
df.Embarked.value_counts().plot('barh').invert_yaxis()

# %%
sns.countplot(x="Embarked", palette="winter", data=df)

# %%
df.Sex.value_counts().plot('bar')

# %%
df[df.Embarked == 'C'].groupby('Sex')['Age'].plot(kind="hist", bins=16, alpha=0.7, legend=True)
# Out:
# Sex
# female    AxesSubplot(0.125,0.125;0.775x0.755)
# male      AxesSubplot(0.125,0.125;0.775x0.755)
# Name: Age, dtype: object

# %%
df.groupby('Sex').Age.mean()
# Out:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %%
# Out:
# Age
# 0.42       8.516700
# 0.67      14.500000
# 0.75      19.258300
# 0.83      23.875000
# 0.92     151.550000
# 1.00      30.005957
# 2.00      37.536250
# 3.00      25.781950
# 4.00      29.543330
# 5.00      22.717700
# 6.00      25.583333
# 7.00      31.687500
# 8.00      28.300000
# 9.00      27.938538
# 10.00     26.025000
# 11.00     54.240625
# 12.00     11.241700
# 13.00     13.364600
# 14.00     42.625700
# 14.50     14.454200
# 15.00     49.655020
# 16.00     25.745100
# 17.00     28.389423
# 18.00     38.063462
# 19.00     27.869496
# 20.00      8.624173
# 20.50      7.250000
# 21.00     31.565621
# 22.00     25.504781
# 23.00     37.994720
#             ...
# 44.00     29.758333
# 45.00     36.818408
# 45.50     17.862500
# 46.00     55.458333
# 47.00     27.601389
# 48.00     37.893067
# 49.00     59.929183
# 50.00     64.025830
# 51.00     28.752386
# 52.00     51.402783
# 53.00     51.479200
# 54.00     44.477087
# 55.00     23.250000
# 55.50      8.050000
# ...

# %%
sns.regplot(x="Age", y="Fare", fit_reg=False, data=df)

# %%
df.plot.scatter(x="Age", y="Fare")

# %%
sns.barplot(x="Sex", y="Survived", hue="Pclass", data=df)

# %%
sns.countplot(x="Sex", hue="Pclass", data=df)

# %%
df[(df.Sex == 'female') & (df.Pclass == 1)].Survived.value_counts()
# Out:
# 1    91
# 0     3
# Name: Survived, dtype: int64

# %%
91/(94)
# Out:
# 0.9680851063829787

# %%
df.groupby(['Sex', 'Survived'])['Pclass'].value_counts().unstack().plot(kind="bar", stacked=True)

# %%
pd.crosstab(df.Sex, df.Pclass)
# Out:
# Pclass    1    2    3
# Sex
# female   94   76  144
# male    122  108  347

# %%
pd.crosstab(df.Sex, df.Survived)
# Out:
# Survived    0    1
# Sex
# female     81  233
# male      468  109

# %%
441/(441+41+95)
# Out:
# 0.7642980935875217

# %%
# This is how to represent a crosstab in a graph:::::
sns.heatmap(pd.crosstab(df.Sex, df.Embarked, normalize="index"), cmap="BrBG", annot=True)
